# %% [markdown]
# <a href="https://colab.research.google.com/github/atsiniloiv/ucmnticmaster-deaplearning-exam/blob/main/examen_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dado que el entrenamiento de redes neuronales es una tarea  muy costosa, **se recomienda ejecutar el notebooks en [Google Colab](https://colab.research.google.com)**, por supuesto también se puede ejecutar en local.
#
# Al entrar en [Google Colab](https://colab.research.google.com) bastará con hacer click en `upload` y subir este notebook. No olvide luego descargarlo en `File->Download .ipynb`
#
# **El examen deberá ser entregado con las celdas ejecutadas, si alguna celda no está ejecutadas no se contará.**

# %% [markdown]
# El examen se divide en dos partes, con la puntuación que se indica a continuación. La puntuación máxima será 10.
#
# - [Actividad 1: Redes Densas](#actividad_1): 5 pts
#     - Correcta normalización: máximo de 0.25 pts
#     - [Cuestión 1](#1.1): 1.5 pt
#     - [Cuestión 2](#1.2): 1.5 pt
#     - [Cuestión 3](#1.3): 0.5 pts
#     - [Cuestión 4](#1.4): 0.25 pts
#     - [Cuestión 5](#1.5): 0.25 pts
#     - [Cuestión 6](#1.6): 0.25 pts
#     - [Cuestión 7](#1.7): 0.25 pts
#     - [Cuestión 8](#1.8): 0.25 pts
#
#
# - [Actividad 2: Redes Convolucionales](#actividad_2): 5 pts
#     - [Cuestión 1](#2.1): 2.5 pt
#     - [Cuestión 2](#2.2): 1 pt
#     - [Cuestión 3](#2.3): 0.5 pts
#     - [Cuestión 4](#2.4): 0.5 pts
#     - [Cuestión 5](#2.5): 0.5 pts

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
tf.random.set_seed(0)

# %% [markdown]
# <a name='actividad_1'></a>
# # Actividad 1: Redes Densas
#
# Para esta primera actividad vamos a utilizar el [wine quality dataset](https://archive.ics.uci.edu/ml/datasets/wine+quality). Con el que trataremos de predecir la calidad del vino.
#
# La calidad del vino puede tomar valores decimales (por ejemplo 7.25), independientemente de que en el dataset de entrenamiento sean números enteros. Por lo tanto, el problema es una `regresión`.
#
# **Puntuación**:
#
# Normalizar las features correctamente (x_train, x_test): 0.25 pts , se pueden normalizar con el [Normalization layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Normalization) de Keras.
#
#
# - Correcta normalización: máximo de 0.25 pts
# - [Cuestión 1](#1.1): 1 pt
# - [Cuestión 2](#1.2): 1 pt
# - [Cuestión 3](#1.3): 0.5 pts
# - [Cuestión 4](#1.4): 0.25 pts
# - [Cuestión 5](#1.5): 0.25 pts
# - [Cuestión 6](#1.6): 0.25 pts
# - [Cuestión 7](#1.7): 0.25 pts
# - [Cuestión 8](#1.8): 0.25 pts

# %%
# Descargar los datos con pandas
df_red = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv',
    sep=';'
)
df_white = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv',
    sep=';'
)
df = pd.concat([df_red, df_white])

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['fixed acidity'].plot(kind='hist', bins=20, title='fixed acidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['volatile acidity'].plot(kind='hist', bins=20, title='volatile acidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['citric acid'].plot(kind='hist', bins=20, title='citric acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['residual sugar'].plot(kind='hist', bins=20, title='residual sugar')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='fixed acidity', y='volatile acidity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='volatile acidity', y='citric acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='citric acid', y='residual sugar', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='residual sugar', y='chlorides', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['fixed acidity'].plot(kind='line', figsize=(8, 4), title='fixed acidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['volatile acidity'].plot(kind='line', figsize=(8, 4), title='volatile acidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['citric acid'].plot(kind='line', figsize=(8, 4), title='citric acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['residual sugar'].plot(kind='line', figsize=(8, 4), title='residual sugar')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
feature_names = [
    'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
    'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'
]

# separar features y target
y = df.pop('quality').values
X = df.copy().values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

print('x_train, y_train shapes:', x_train.shape, y_train.shape)
print('x_test, y_test shapes:', x_test.shape, y_test.shape)
print('Some qualities: ', y_train[:5])
# Out:
# x_train, y_train shapes: (4872, 11) (4872,)
# x_test, y_test shapes: (1625, 11) (1625,)
# Some qualities:  [6 7 8 5 6]

# %%
## Normalizar las features

from tensorflow.keras.layers import Normalization
normalizer = keras.layers.Normalization()
normalizer.adapt(x_train) # voy a normalizar usando los parámetros aprendidos de x_train
x_train_norm = normalizer(x_train)
x_test_norm = normalizer(x_test) # x_test_norm puede no tener media 0 y std 1 exactos
# ya que está normalizado usando los parámetros aprendidos de x_train

x_train_norm[1,:] # visualizo los valores de las variable normalizadas en datos de entrenamiento
# Out:
# <tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([-0.7853838 , -1.0907232 ,  0.07390133, -0.9196466 ,  0.0222696 ,
#        -0.5301523 , -0.596653  , -1.2502729 ,  0.6399148 , -0.47886032,
#         0.34073704], dtype=float32)>

# %% [markdown]
# <a name='1.1'></a>
# ## Cuestión 1: Cree un modelo secuencial que contenga 4 capas ocultas(hidden layers), con más de 60 neuronas  por capa, sin regularización y obtenga los resultados.
#
# Puntuación:
# - Obtener el modelo correcto: 0.8 pts
# - Compilar el modelo: 0.1pts
# - Acertar con la función de pérdida: 0.1 pts

# %%
# Definir el modelo
model_1 = keras.Sequential([
    keras.Input(shape=(11, )),
    layers.Dense(65, activation='relu', name='layer1'), # uso relu como función de activación en las capas ocultas
    layers.Dense(65, activation='relu', name='layer2'),
    layers.Dense(65, activation='relu', name='layer3'),
    layers.Dense(65, activation='relu', name='layer4'), # 4 capas ocultas de 65 neuronas cada una
    layers.Dense(1, activation='linear', name='layerout') # uso linear para tener una salida libre (float)
])

model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ (None, 65)             │           780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ (None, 65)             │         4,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer3 (Dense)                  │ (None, 65)             │         4,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer4 (Dense)                  │ (None, 65)             │         4,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layerout (Dense)                │ (None, 1)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,716 (53.58 KB)
#  Trainable params: 13,716 (53.58 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilar el modelo

model_1.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae'] # por ver también esta métrica, además del mean squared error
)

# %%
# No modifique el código
model_1.fit(x_train_norm,
          y_train,
          epochs=200,
          batch_size=32,
          validation_split=0.2,
          verbose=1)
# Out:
# Epoch 1/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 10.7377 - mae: 2.6118 - val_loss: 1.6216 - val_mae: 0.9285
# Epoch 2/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1950 - mae: 0.8569 - val_loss: 0.9644 - val_mae: 0.7234
# Epoch 3/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7713 - mae: 0.6891 - val_loss: 0.7028 - val_mae: 0.6273
# Epoch 4/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6010 - mae: 0.6049 - val_loss: 0.6009 - val_mae: 0.5848
# Epoch 5/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5311 - mae: 0.5656 - val_loss: 0.5694 - val_mae: 0.5713
# Epoch 6/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5007 - mae: 0.5482 - val_loss: 0.5521 - val_mae: 0.5653
# Epoch 7/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.
200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0803 - mae: 0.2192 - val_loss: 0.6790 - val_mae: 0.6269
# Epoch 176/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0806 - mae: 0.2190 - val_loss: 0.6836 - val_mae: 0.6078
# Epoch 177/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0836 - mae: 0.2246 - val_loss: 0.6890 - val_mae: 0.6232
# Epoch 178/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0887 - mae: 0.2319 - val_loss: 0.6940 - val_mae: 0.6164
# Epoch 179/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0988 - mae: 0.2411 - val_loss: 0.6455 - val_mae: 0.5916
# Epoch 180/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1082 - mae: 0.2544 - val_loss: 0.6731 - val_mae: 0.6013
# Epoch 181/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1122 - mae: 0.2639 - val_loss: 0.7013 - val_mae: 0.6148
# Epoch 182/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1302 - mae: 0.2864 - val_loss: 0.6723 - val_mae: 0.6053
# Epoch 183/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1292 - mae: 0.2861 - val_loss: 0.6203 - val_mae: 0.5781
# Epoch 184/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1130 - mae: 0.2643 - val_loss: 0.6082 - val_mae: 0.5692
# Epoch 185/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0942 - mae: 0.2406 - val_loss: 0.6308 - val_mae: 0.5731
# Epoch 186/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0927 - mae: 0.2401 - val_loss: 0.6286 - val_mae: 0.5793
# Epoch 187/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0899 - mae: 0.2344 - val_loss: 0.6406 - val_mae: 0.5839
# Epoch 188/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - mae: 0.2364 - val_loss: 0.6269 - val_mae: 0.5794
# Epoch 189/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0930 - mae: 0.2381 - val_loss: 0.6555 - val_mae: 0.5959
# Epoch 190/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1011 - mae: 0.2500 - val_loss: 0.7001 - val_mae: 0.6202
# Epoch 191/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1135 - mae: 0.2655 - val_loss: 0.8057 - val_mae: 0.6793
# Epoch 192/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1375 - mae: 0.2956 - val_loss: 0.8600 - val_mae: 0.7178
# Epoch 193/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1694 - mae: 0.3288 - val_loss: 0.8271 - val_mae: 0.6926
# Epoch 194/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1639 - mae: 0.3227 - val_loss: 0.6963 - val_mae: 0.6174
# Epoch 195/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1339 - mae: 0.2871 - val_loss: 0.6542 - val_mae: 0.5931
# Epoch 196/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1051 - mae: 0.2540 - val_loss: 0.6327 - val_mae: 0.5744
# Epoch 197/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0783 - mae: 0.2182 - val_loss: 0.6483 - val_mae: 0.5826
# Epoch 198/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0645 - mae: 0.1957 - val_loss: 0.6512 - val_mae: 0.5876
# Epoch 199/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0566 - mae: 0.1819 - val_loss: 0.6571 - val_mae: 0.5854
# Epoch 200/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0501 - mae: 0.1698 - val_loss: 0.6551 - val_mae: 0.5872

# %%
# No modifique el código
results_1 = model_1.evaluate(x_test_norm, y_test, verbose=1)
print('Test Loss: {}'.format(results_1))
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6989 - mae: 0.5944
# Test Loss: [0.7166657447814941, 0.5940437912940979]

# %% [markdown]
# <a name='1.2'></a>
# ## Cuestión 2: Utilice el mismo modelo de la cuestión anterior pero añadiendo al menos dos técnicas distinas de regularización.
#
# Ejemplos de regularización: [Prevent_Overfitting.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb)
#
# Puntuación:
#
# - Obtener el modelo con la regularización: 0.8 pts
# - Obtener un `test loss` inferior al anterior: 0.2 pts

# %%
# Una manera de regularizar el modelo es hacerlo más simple, con un menor número de parámetros.
# Por lo tanto eliminé una de las capas ocultas y dejé el modelo en 3.
# También incluyo un Dropout layer después de cada capa oculta para
# 'apagar' aleatoriamente un 30% de las neuronas durante el entrenamiento.
model_2 = keras.Sequential([
    keras.Input(shape=(11, )),
    layers.Dense(65, activation='relu', name='layer1'),
    layers.Dropout(0.3, name='dropout_layer1'),
    layers.Dense(65, activation='relu', name='layer2'),
    layers.Dropout(0.3, name='dropout_layer2'),
    layers.Dense(65, activation='relu', name='layer3'),
    layers.Dropout(0.3, name='dropout_layer3'),
    layers.Dense(1, activation='linear', name='layerout')
])

model_2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ (None, 65)             │           780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer1 (Dropout)        │ (None, 65)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ (None, 65)             │         4,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer2 (Dropout)        │ (None, 65)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer3 (Dense)                  │ (None, 65)             │         4,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer3 (Dropout)        │ (None, 65)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layerout (Dense)                │ (None, 1)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,426 (36.82 KB)
#  Trainable params: 9,426 (36.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilación del modelo
model_2.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae'] # por ver también esta métrica, además del mean squared error
)

# %%
# Otro método de regularización es reducir el batch size de manera que el modelo actualiza los pesos
# cada 32 muestras y no después de cada una.
batch_size=32

# %%
# No modifique el código
model_2.fit(x_train_norm,
          y_train,
          epochs=200,
          batch_size=batch_size,
          validation_split=0.2,
          verbose=1)
# Out:
# Epoch 1/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 17.0997 - mae: 3.5748 - val_loss: 2.4199 - val_mae: 1.1886
# Epoch 2/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2717 - mae: 1.4493 - val_loss: 1.7531 - val_mae: 1.0344
# Epoch 3/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4581 - mae: 1.2389 - val_loss: 1.2602 - val_mae: 0.8530
# Epoch 4/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1881 - mae: 1.1794 - val_loss: 1.1232 - val_mae: 0.8187
# Epoch 5/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7859 - mae: 1.0670 - val_loss: 0.9158 - val_mae: 0.7371
# Epoch 6/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5399 - mae: 0.9889 - val_loss: 0.8790 - val_mae: 0.7180
# Epoch 7/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4612 - mae: 0.9603 - val_loss: 0.9294 - val_mae: 0.7499
# Epoch 8/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4346 - mae: 0.9458 - val_loss: 0.9320 - val_mae: 0.7578
# Epoch 9/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3445 - mae: 0.9011 - val_loss: 0.7819 - val_mae: 0.6841
# Epoch 10/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2668 - mae: 0.8900 - val_loss: 0.7386 - val_mae: 0.6601
# Epoch 11/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2317 - mae: 0.8690 - val_loss: 0.6754 - val_mae: 0.6341
# Epoch 12/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1522 - mae: 0.8567 - val_loss: 0.6245 - val_mae: 0.6086
# Epoch 13/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1560 - mae: 0.8545 - val_loss: 0.6969 - val_mae: 0.6447
# Epoch 14/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1754 - mae: 0.8517 - val_loss: 0.5589 - val_mae: 0.5770
# Epoch 15/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1749 - mae: 0.8537 - val_loss: 0.6072 - val_mae: 0.6023
# Epoch 16/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0553 - mae: 0.8097 - val_loss: 0.5842 - val_mae: 0.5907
# Epoch 17/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0252 - mae: 0.7980 - val_loss: 0.6175 - val_mae: 0.6065
# Epoch 18/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0548 - mae: 0.8138 - val_loss: 0.5415 - val_mae: 0.5676
# Epoch 19/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9762 - mae: 0.7772 - val_loss: 0.5893 - val_mae: 0.5912
# Epoch 20/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0150 - mae: 0.7969 - val_loss: 0.5517 - val_mae: 0.5727
# Epoch 21/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.
200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4111 - mae: 0.4923 - val_loss: 0.4483 - val_mae: 0.5246
# Epoch 191/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4389 - mae: 0.5095 - val_loss: 0.4401 - val_mae: 0.5244
# Epoch 192/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4200 - mae: 0.5047 - val_loss: 0.4535 - val_mae: 0.5302
# Epoch 193/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4188 - mae: 0.4975 - val_loss: 0.4597 - val_mae: 0.5329
# Epoch 194/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4122 - mae: 0.4992 - val_loss: 0.4443 - val_mae: 0.5241
# Epoch 195/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4115 - mae: 0.4961 - val_loss: 0.4496 - val_mae: 0.5276
# Epoch 196/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4121 - mae: 0.4981 - val_loss: 0.4477 - val_mae: 0.5226
# Epoch 197/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4140 - mae: 0.4924 - val_loss: 0.4638 - val_mae: 0.5310
# Epoch 198/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4097 - mae: 0.4919 - val_loss: 0.4505 - val_mae: 0.5283
# Epoch 199/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4020 - mae: 0.4885 - val_loss: 0.4369 - val_mae: 0.5182
# Epoch 200/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3833 - mae: 0.4772 - val_loss: 0.4635 - val_mae: 0.5277

# %%
# No modifique el código
results_2 = model_2.evaluate(x_test_norm, y_test, verbose=1)
print('Test Loss: {}'.format(results_2))
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4456 - mae: 0.5202
# Test Loss: [0.4689842164516449, 0.5311887860298157]

# %% [markdown]
# <a name='1.3'></a>
# ## Cuestión 3: Utilice el mismo modelo de la cuestión anterior pero añadiendo un callback de early stopping.

# %%
# Utilizo la clase EarlyStopping de keras, el monitor será val_loss, es decir
# el mse sobre el conjunto de validación que en mi caso será el 20% de los datos de entrenamiento
callback = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=3, # número de épicas sin mejora significativa en el val_loss
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# Defino el modelo 3, que es igual al anterior anadiendo el callback de early stopping
model_3 = keras.Sequential([
    keras.Input(shape=(11, )),
    layers.Dense(65, activation='relu', name='layer1'),
    layers.Dropout(0.3, name='dropout_layer1'),
    layers.Dense(65, activation='relu', name='layer2'),
    layers.Dropout(0.3, name='dropout_layer2'),
    layers.Dense(65, activation='relu', name='layer3'),
    layers.Dropout(0.3, name='dropout_layer3'),
    layers.Dense(1, activation='linear', name='layerout')
])

model_3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ (None, 65)             │           780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer1 (Dropout)        │ (None, 65)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ (None, 65)             │         4,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer2 (Dropout)        │ (None, 65)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer3 (Dense)                  │ (None, 65)             │         4,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer3 (Dropout)        │ (None, 65)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layerout (Dense)                │ (None, 1)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,426 (36.82 KB)
#  Trainable params: 9,426 (36.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilación del modelo
model_3.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae'] # por ver también esta métrica, además del mean squared error
)

# %%
## definir el early stopping callback
model_3.fit(x_train_norm,
          y_train,
          epochs=200,
          batch_size=batch_size,
          validation_split=0.2,
          verbose=1,
          callbacks=[callback]
)
# Out:
# Epoch 1/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 15.8962 - mae: 3.4253 - val_loss: 2.2072 - val_mae: 1.1390
# Epoch 2/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2.9776 - mae: 1.3759 - val_loss: 1.4969 - val_mae: 0.9258
# Epoch 3/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.2677 - mae: 1.2050 - val_loss: 1.4149 - val_mae: 0.9576
# Epoch 4/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.8879 - mae: 1.0907 - val_loss: 1.0661 - val_mae: 0.8162
# Epoch 5/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6205 - mae: 1.0014 - val_loss: 0.8155 - val_mae: 0.6936
# Epoch 6/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4521 - mae: 0.9563 - val_loss: 0.9099 - val_mae: 0.7493
# Epoch 7/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3527 - mae: 0.9141 - val_loss: 0.9203 - val_mae: 0.7590
# Epoch 8/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1694 - mae: 0.8579 - val_loss: 0.7731 - val_mae: 0.6765
# Epoch 9/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2152 - mae: 0.8598 - val_loss: 0.7845 - val_mae: 0.6863
# Epoch 10/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1376 - mae: 0.8348 - val_loss: 0.7010 - val_mae: 0.6408
# Epoch 11/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0307 - mae: 0.8040 - val_loss: 0.6460 - val_mae: 0.6142
# Epoch 12/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0127 - mae: 0.7880 - val_loss: 0.5887 - val_mae: 0.5832
# Epoch 13/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0174 - mae: 0.7945 - val_loss: 0.6092 - val_mae: 0.5966
# Epoch 14/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0396 - mae: 0.7911 - val_loss: 0.5983 - val_mae: 0.5944
# Epoch 15/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0004 - mae: 0.7883 - val_loss: 0.5418 - val_mae: 0.5717
# Epoch 16/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9551 - mae: 0.7728 - val_loss: 0.5196 - val_mae: 0.5586
# Epoch 17/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9128 - mae: 0.7567 - val_loss: 0.5384 - val_mae: 0.5637
# Epoch 18/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9195 - mae: 0.7510 - val_loss: 0.5377 - val_mae: 0.5673
# Epoch 19/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9108 - mae: 0.7494 - val_loss: 0.5711 - val_mae: 0.5785
# Epoch 19: early stopping

# %%
# No modifique el código
results = model_3.evaluate(x_test_norm, y_test, verbose=1)
print('Test Loss: {}'.format(results))
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5855 - mae: 0.5917
# Test Loss: [0.5889086723327637, 0.5918066501617432]

# %% [markdown]
# <a name='1.4'></a>
# ## Cuestión 4: ¿Podría haberse usado otra función de activación de la neurona de salida? En caso afirmativo especifíquela.

# %% [markdown]
# En este caso podría haber utilizado una función de activación relu (rectified linear unit) por que la variable objetivo es la calidad del vino, que toma valores positivos de 1 a 10.

# %% [markdown]
# <a name='1.5'></a>
# ## Cuestión 5:  ¿Qué es lo que una neurona calcula?
#
# **a)** Una función de activación seguida de una suma ponderada  de las entradas.
#
# **b)** Una suma ponderada  de las entradas seguida de una función de activación.
#
# **c)** Una función de pérdida, definida sobre el target.
#
# **d)** Ninguna  de las anteriores es correcta

# %% [markdown]
# **b) Una suma ponderada de las entradas seguida de una función de activación.**

# %% [markdown]
# <a name='1.6'></a>
# ## Cuestión 6:  ¿Cuál de estas funciones de activación no debería usarse en una capa oculta (hidden layer)?
#
# **a)** `sigmoid`
#
# **b)** `tanh`
#
# **c)** `relu`
#
# **d)** `linear`

# %% [markdown]
# **d) linear**
#
# Si todas las capas ocultas usan activación lineal la red entera se comporta como una sola capa lineal y por lo tanto el modelo no es capaz de modelizar funciones complejas.

# %% [markdown]
# <a name='1.7'></a>
# ## Cuestión 7:  ¿Cuál de estas técnicas es efectiva para combatir el overfitting en una red con varias capas ocultas? Ponga todas las que lo sean.
#
# **a)** Dropout
#
# **b)** Regularización L2.
#
# **c)** Aumentar el tamaño del test set.
#
# **d)** Aumentar el tamaño del validation set.
#
# **e)** Reducir el número de capas de la red.
#
# **f)** Data augmentation.

# %% [markdown]
# a) Dropout
# b) Regularización L2.
# e) Reducir el número de capas de la red.
# f) Data augmentation.
#
# Aumentar el número de muestras de test no reduce el overfitting porque el modelo se entrena con los datos train.
# Aumentar el número de muestras de validación tampoco mejora el overfitting, como mucho ayuda a detectarlo.

# %% [markdown]
# <a name='1.8'></a>
# ## Cuestión 8:  Supongamos que queremos entrenar una red para un problema de clasificación de imágenes con las siguientes clases: {'perro','gato','persona'}. ¿Cuántas neuronas y que función de activación debería tener la capa de salida? ¿Qué función de pérdida (loss function) debería usarse?

# %% [markdown]
# Necesito una neurona por clase, por lo tanto 3 neuronas. La función de la capa de salida sería una softmax, que se usa en problemas de clasificación multiclase. La función de pérdida sería la categorical_crossentropy, de forma que asignaría las salidas [1,0,0] para perro, [0,1,0] para gato y [0,0,1] para persona, por ejemplo.

# %% [markdown]
# <a name='actividad_2'></a>
# # Actividad 2: Redes Convolucionales
#
# Vamos a usar el dataset [cifar-10](https://www.cs.toronto.edu/~kriz/cifar.html), que son 60000 imágenes de 32x32 a color  con 10 clases diferentes. Para realizar mejor la práctica puede consultar [Introduction_to_CNN.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/CNN/Introduction_to_CNN.ipynb).
#
#
#
# **Puntuación**:
#
# - [Cuestión 1](#2.1): 2.5 pt
# - [Cuestión 2](#2.2): 1 pt
# - [Cuestión 3](#2.3): 0.5 pts
# - [Cuestión 4](#2.4): 0.5 pts
# - [Cuestión 5](#2.5): 0.5 pts
#
# Puede normalizar las imágenes al principio o usar la capa [Rescaling](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Rescaling):
#
# ```python
# tf.keras.layers.experimental.preprocessing.Rescaling(
#     scale, offset=0.0, name=None, **kwargs
# )
# ```

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
print('x_train, y_train shapes:', x_train.shape, y_train.shape)
print('x_test, y_test shapes:', x_test.shape, y_test.shape)
# Out:
# x_train, y_train shapes: (50000, 32, 32, 3) (50000,)
# x_test, y_test shapes: (10000, 32, 32, 3) (10000,)

# %% [markdown]
# <a name='2.1'></a>
# ## Cuestión 1: Cree una red convolucional con la API funcional con al menos dos capas convolucionales y al menos dos capas de pooling. Debe obtener un `Test accuracy > 0.68`

# %%
# reescaling
image_size = (32, 32)  # específico del dataset CIFAR-10, lo pone el enunciado
inputs = tf.keras.Input(shape=image_size + (3,), name='input')
reescaling = tf.keras.layers.Rescaling(1. / 255)(inputs)

# Convolution + pooling layers
# Layer 1
conv_1 = layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu',
                       name='conv_1')(reescaling)
pool_1 = layers.MaxPooling2D(pool_size=(2, 2), name='pool_1')(conv_1)

# Layer 2
conv_2 = layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu',
                       name='conv_2')(pool_1)
pool_2 = layers.MaxPooling2D(pool_size=(2, 2), name='pool_2')(conv_2)

# Layer 3
conv_3 = layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu',
                       name='conv_3')(pool_2)
pool_3 = layers.MaxPooling2D(pool_size=(2, 2), name='pool_3')(conv_3)

# Flattening
flat = layers.Flatten(name='flatten')(pool_3)
dense = layers.Dense(64, activation='relu', name='dense')(flat)

# Fully-connected
outputs = layers.Dense(10, activation='softmax', name='output')(dense) # hay 10 clases

model = keras.Model(inputs=inputs, outputs=outputs, name='cnn_cifar10')
model.summary()
# Out:
# Model: "cnn_cifar10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_1 (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_1 (MaxPooling2D)           │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_2 (Conv2D)                 │ (None, 16, 16, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_2 (MaxPooling2D)           │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_3 (Conv2D)                 │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_3 (MaxPooling2D)           │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,890 (370.66 KB)
#  Trainable params: 94,890 (370.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=4,
    verbose=1)
history = model.fit(x_train, y_train, epochs=25, batch_size=64,
                    validation_split=0.15, verbose=1, callbacks=callback)
# Out:
# Epoch 1/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.3213 - loss: 1.8536 - val_accuracy: 0.5073 - val_loss: 1.3774
# Epoch 2/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5417 - loss: 1.2812 - val_accuracy: 0.5733 - val_loss: 1.2119
# Epoch 3/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6188 - loss: 1.0893 - val_accuracy: 0.6315 - val_loss: 1.0722
# Epoch 4/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6636 - loss: 0.9670 - val_accuracy: 0.6428 - val_loss: 1.0446
# Epoch 5/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6903 - loss: 0.8890 - val_accuracy: 0.6623 - val_loss: 0.9688
# Epoch 6/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7152 - loss: 0.8245 - val_accuracy: 0.6751 - val_loss: 0.9489
# Epoch 7/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7332 - loss: 0.7761 - val_accuracy: 0.6839 - val_loss: 0.9238
# Epoch 8/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7498 - loss: 0.7333 - val_accuracy: 0.6919 - val_loss: 0.9095
# Epoch 9/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7609 - loss: 0.7003 - val_accuracy: 0.7003 - val_loss: 0.8861
# Epoch 10/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7727 - loss: 0.6612 - val_accuracy: 0.7005 - val_loss: 0.9057
# Epoch 11/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7843 - loss: 0.6311 - val_accuracy: 0.6983 - val_loss: 0.9159
# Epoch 12/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7887 - loss: 0.6077 - val_accuracy: 0.6801 - val_loss: 0.9968
# Epoch 13/25
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7977 - loss: 0.5849 - val_accuracy: 0.6897 - val_loss: 0.9838
# Epoch 13: early stopping

# %%
results = model.evaluate(x_test, y_test, verbose=0, batch_size=1000)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.99917072057724
# Test Accuracy: 0.6811000108718872

# %% [markdown]
# <a name='2.2'></a>
# ## Cuestión 2: Cree el mismo  modelo de manera secuencial. No es necesario compilar ni entrenar el modelo

# %%
model_seq = tf.keras.models.Sequential()
# Código aquí
...

# %% [markdown]
# <a name='2.3'></a>
# ## Cuestión 3: Si tenenemos una  una imagen de entrada de 300 x 300 a color (RGB) y queremos usar una red densa. Si la primera capa oculta tiene 100 neuronas, ¿Cuántos parámetros tendrá esa capa (sin incluir el bias) ?

# %% [markdown]
# <a name='2.4'></a>
# ## Cuestión 4   Ponga  las verdaderas ventajas de las redes convolucionales respecto a las densas
#
# **a)** Reducen el número total de parámetros, reduciendo así el overfitting.
#
# **b)** Permiten utilizar una misma 'función'  en varias localizaciones de la imagen de entrada, en lugar de aprender una función diferente para cada pixel.
#
# **c)** Permiten el uso del transfer learning.
#
# **d)** Generalmente son menos profundas, lo que facilita su entrenamiento.

# %% [markdown]
# <a name='2.5'></a>
# ## Cuestión 5: Para el procesamiento de series temporales las redes convolucionales no son efectivas, habrá que usar redes recurrentes.
#
# - **Verdadero**
# - **Falso**
